# %% [markdown]
# # NZ Admin jobs data exploration

# %% [markdown]
# ## 1. Load data and overview

# %%
import pandas as pd
import re

# %%
# load file
df = pd.read_excel('NZ_Admin_JOBS.xlsx')

# %%
# get info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2708 entries, 0 to 2707
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   字段1       2708 non-null   object
#  1   字段1_link  2708 non-null   object
#  2   字段2       2686 non-null   object
#  3   字段3       2708 non-null   object
#  4   字段4       2708 non-null   object
#  5   字段5       2708 non-null   object
# dtypes: object(6)
# memory usage: 127.1+ KB

# %% [markdown]
# #### Total 2,708 observations, 6 columns
# #### No column name, all data are object

# %%
df.describe()
# Out:
#                         字段1  \
# count                  2708
# unique                  548
# top     Executive Assistant
# freq                    301
#
#                                                  字段1_link  \
# count                                                2708
# unique                                               2708
# top     https://www.seek.co.nz/job/50582301?type=promo...
# freq                                                    1
#
#                                                       字段2  \
# count                                                2686
# unique                                                475
# top     Beyond Recruitment - Winner – Best Innovation ...
# freq                                                  285
#
#                                                       字段3         字段4  \
# count                                                2708        2708
# unique                                                147          54
# top     location: AucklandAucklandarea: Auckland Centr...  27d ago,at
# freq                                                  654         572
#
#                                                       字段5
# count                                                2708
# unique                                                 93
# top     classification: Administration & Office Suppor...
# freq                                                  715

# %% [markdown]
# #### '字段1_link' could be index
# #### 22 Missing value in '字段2'
# #### Column '字段1' contains position
# #### Column '字段1_link'contains link
# #### Column '字段2'  contains company name
# #### Column '字段3' contains location
# #### Column '字段4' shows release time
# #### Column '字段5' contains position classification

# %%
df.head(5)
# Out:
#                                     字段1  \
# 0                         Administrator
# 1                          Receptionist
# 2          Prosecutions Support Officer
# 3  Early Childhood Centre Administrator
# 4        Business Support Administrator
#
#                                             字段1_link  \
# 0  https://www.seek.co.nz/job/50582301?type=promo...
# 1  https://www.seek.co.nz/job/50620889?type=promo...
# 2  https://www.seek.co.nz/job/50622169?type=stand...
# 3  https://www.seek.co.nz/job/50639620?type=stand...
# 4  https://www.seek.co.nz/job/50622432?type=stand...
#
#                                         字段2  \
# 0                                       NaN
# 1                      Avenues Orthodontics
# 2                        New Zealand Police
# 3  Kew Pacific Island Early Learning Centre
# 4                                       NaN
#
#                                                  字段3  \
# 0  location: Bay of PlentyBay of Plentyarea: Taur...
# 1  location: Bay of PlentyBay of Plentyarea: Taur...
# 2                         location: AucklandAuckland
# 3  location: SouthlandSouthlandarea: Invercargill...
# 4  location: CanterburyCanterburyarea: Christchur...
#
#                               字段4  \
# 0  Featured,at,Private Advertiser
# 1                     Featured,at
# 2                       4d ago,at
# 3                       1h ago,at
# 4    4d ago,at,Private Advertiser
#
#                                                  字段5
# 0  classification: Administration & Office Suppor...
# 1  classification: Administration & Office Suppor...
# 2  classification: Administration & Office Suppor...
# 3  classification: Administration & Office Suppor...
# 4  classification: Administration & Office Suppor...

# %% [markdown]
# ### Poor data quality
# #### 1. No column name;
# #### 2. No index;
# #### 3. Null value;
# #### 4. Duplicate value;
# #### 5. Upper case and lower case mixed;
# #### 6. Abbreviation and full name mixed;
# #### 7. Time data is not clear
# #### 8. Missing data
# #### 9. Data mixed in one column
# #### 10. Salary format is different;
# #### 11. Classification is too long. Parent classification are the same.

# %% [markdown]
# ## 2. Data preprocess

# %% [markdown]
# #### 2.1 Add column name

# %%
df_copy = df.copy()

# %%
# add column name first
column_name = ['Position','Link','Company','Location','Release_time','Classification']
df_copy.columns = column_name
df_copy.head(1)
# Out:
#         Position                                               Link Company  \
# 0  Administrator  https://www.seek.co.nz/job/50582301?type=promo...     NaN
#
#                                             Location  \
# 0  location: Bay of PlentyBay of Plentyarea: Taur...
#
#                      Release_time  \
# 0  Featured,at,Private Advertiser
#
#                                       Classification
# 0  classification: Administration & Office Suppor...

# %% [markdown]
# #### 2.2 Clean column 'Position'

# %% [markdown]
# #### 'office administrator' and 'Office Administrator' should be the same position
#
# #### 2.2.1 Capitalize each word in Column 'Position'

# %%
# Capitalize the value
df_copy['Position'] = df_copy['Position'].str.title()
df_copy.head(5)
# Out:
#                                Position  \
# 0                         Administrator
# 1                          Receptionist
# 2          Prosecutions Support Officer
# 3  Early Childhood Centre Administrator
# 4        Business Support Administrator
#
#                                                 Link  \
# 0  https://www.seek.co.nz/job/50582301?type=promo...
# 1  https://www.seek.co.nz/job/50620889?type=promo...
# 2  https://www.seek.co.nz/job/50622169?type=stand...
# 3  https://www.seek.co.nz/job/50639620?type=stand...
# 4  https://www.seek.co.nz/job/50622432?type=stand...
#
#                                     Company  \
# 0                                       NaN
# 1                      Avenues Orthodontics
# 2                        New Zealand Police
# 3  Kew Pacific Island Early Learning Centre
# 4                                       NaN
#
#                                             Location  \
# 0  location: Bay of PlentyBay of Plentyarea: Taur...
# 1  location: Bay of PlentyBay of Plentyarea: Taur...
# 2                         location: AucklandAuckland
# 3  location: SouthlandSouthlandarea: Invercargill...
# 4  location: CanterburyCanterburyarea: Christchur...
#
#                      Release_time  \
# 0  Featured,at,Private Advertiser
# 1                     Featured,at
# 2                       4d ago,at
# 3                       1h ago,at
# 4    4d ago,at,Private Advertiser
#
#                                       Classification
# 0  classification: Administration & Office Suppor...
# 1  classification: Administration & Office Suppor...
# 2  classification: Administration & Office Suppor...
# 3  classification: Administration & Office Suppor...
# 4  classification: Administration & Office Suppor...

# %% [markdown]
# #### Column 'Position' inlcude work type description, like 'full time','part time','10hours per week','temp'...
# #### 2.2.2 Create and fill in Column 'Work type'

# %%
# select work type
print(df_copy['Position'].str.contains("[Ff]ull").sum()) #5
print(df_copy['Position'].str.contains("[Pp]art").sum()) #41
print(df_copy['Position'].str.contains("[Ff]ix").sum()) #20
print(df_copy['Position'].str.contains("[Pp]er").sum()) #308
print(df_copy['Position'].str.contains("[Cc]ontract").sum()) #96
df_copy['Worktype'] = df_copy.loc[df_copy['Position'].str.contains("[Ff]ull|[Pp]art|[Ff]ix|[Pp]er|[Cc]ontract"),'Position']
# Out:
# 5
# 41
# 20
# 308
# 96

# %% [markdown]
# #### 2.2.3 Clean column 'Link'
# #### job/50582301? number between'/' and '?' seems company ID

# %%
# filter companyID from Link

pattern = r"\d{8}"
df_copy['CompanyID'] = df_copy['Link'].apply(lambda x: re.findall(pattern,x)[0])
df_copy.head(1)
# Out:
#         Position                                               Link Company  \
# 0  Administrator  https://www.seek.co.nz/job/50582301?type=promo...     NaN
#
#                                             Location  \
# 0  location: Bay of PlentyBay of Plentyarea: Taur...
#
#                      Release_time  \
# 0  Featured,at,Private Advertiser
#
#                                       Classification Worktype CompanyID
# 0  classification: Administration & Office Suppor...      NaN  50582301

# %% [markdown]
# #### 2.2.4 Clean column 'Company'

# %%
# To find 22 missing value records in Column 'Company'
df_copy[df_copy['Company'].isnull()].head(5)
# Out:
#                                     Position  \
# 0                              Administrator
# 4             Business Support Administrator
# 19                             Administrator
# 60                             Administrator
# 64  Administration Specialist - Construction
#
#                                                  Link Company  \
# 0   https://www.seek.co.nz/job/50582301?type=promo...     NaN
# 4   https://www.seek.co.nz/job/50622432?type=stand...     NaN
# 19  https://www.seek.co.nz/job/50604829?type=stand...     NaN
# 60  https://www.seek.co.nz/job/50582301?type=stand...     NaN
# 64  https://www.seek.co.nz/job/50638765?type=stand...     NaN
#
#                                              Location  \
# 0   location: Bay of PlentyBay of Plentyarea: Taur...
# 4   location: CanterburyCanterburyarea: Christchur...
# 19  location: ManawatuManawatuarea: Rest of Manawa...
# 60  location: Bay of PlentyBay of Plentyarea: Taur...
# 64  location: AucklandAucklandarea: Rodney & North...
#
#                       Release_time  \
# 0   Featured,at,Private Advertiser
# 4     4d ago,at,Private Advertiser
# 19    7d ago,at,Private Advertiser
# 60   11d ago,at,Private Advertiser
# 64    5h ago,at,Private Advertiser
#
#                                        Classification Worktype CompanyID
# 0   classification: Administration & Office Suppor...      NaN  50582301
# 4   classification: Administration & Office Suppor...      NaN  50622432
# 19  classification: Administration & Office Suppor...      NaN  50604829
# 60  classification: Administration & Office Suppor...      NaN  50582301
# 64  classification: Administration & Office Suppor...      NaN  50638765

# %% [markdown]
# #### I found that 22 null in company because they are private advertisers
# #### Next, I will fill "Private Advertiser" in them

# %%
# fill null value by 'Private Advertiser'
df_copy['Company'] = df_copy['Company'].fillna(value = 'Private Advertiser')
df_copy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2708 entries, 0 to 2707
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Position        2708 non-null   object
#  1   Link            2708 non-null   object
#  2   Company         2708 non-null   object
#  3   Location        2708 non-null   object
#  4   Release_time    2708 non-null   object
#  5   Classification  2708 non-null   object
#  6   Worktype        454 non-null    object
#  7   CompanyID       2708 non-null   object
# dtypes: object(8)
# memory usage: 169.4+ KB

# %% [markdown]
# #### 2.2.5 Deal with column 'Location'
# #### inlcude wage data, extra word like"location:"

# %%
# check number of wage data inlcuded in Column'Location'
print(df_copy['Location'].str.contains(',').sum()) # 603
# Out:
# 603

# %% [markdown]
# #### 603 Location data include wage

# %%
# delete wage data in Column 'Locaiton'
df_copy['Location'] = df_copy['Location'].apply(lambda x: x.split(',')[0] if "," in x else x)

# %%
print(df_copy['Location'].str.contains(',').sum())
# Out:
# 0

# %%
# create a column include salary
df_copy['Salary'] = df_copy['Location'].apply(lambda x: x.split(',')[1] if "," in x else "")

# %%
 # remove extra word "location:"
df_copy['Location'] = df_copy['Location'].apply(lambda x: x[9:])

# %%
df_copy['Area'] = df_copy['Location'].apply(lambda x: x.split(':')[0])
df_copy.head(5)
# Out:
#                                Position  \
# 0                         Administrator
# 1                          Receptionist
# 2          Prosecutions Support Officer
# 3  Early Childhood Centre Administrator
# 4        Business Support Administrator
#
#                                                 Link  \
# 0  https://www.seek.co.nz/job/50582301?type=promo...
# 1  https://www.seek.co.nz/job/50620889?type=promo...
# 2  https://www.seek.co.nz/job/50622169?type=stand...
# 3  https://www.seek.co.nz/job/50639620?type=stand...
# 4  https://www.seek.co.nz/job/50622432?type=stand...
#
#                                     Company  \
# 0                        Private Advertiser
# 1                      Avenues Orthodontics
# 2                        New Zealand Police
# 3  Kew Pacific Island Early Learning Centre
# 4                        Private Advertiser
#
#                                             Location  \
# 0   Bay of PlentyBay of Plentyarea: TaurangaTauranga
# 1   Bay of PlentyBay of Plentyarea: TaurangaTauranga
# 2                                   AucklandAuckland
# 3   SouthlandSouthlandarea: InvercargillInvercargill
# 4   CanterburyCanterburyarea: ChristchurchChristc...
#
#                      Release_time  \
# 0  Featured,at,Private Advertiser
# 1                     Featured,at
# 2                       4d ago,at
# 3                       1h ago,at
# 4    4d ago,at,Private Advertiser
#
#                                       Classification Worktype CompanyID  \
# 0  classification: Administration & Office Suppor...      NaN  50582301
# 1  classification: Administration & Office Suppor...      NaN  50620889
# 2  classification: Administration & Office Suppor...      NaN  50622169
# 3  classification: Administration & Office Suppor...      NaN  50639620
# 4  classification: Administration & Office Suppor...      NaN  50622432
#
#   Salary                             Area
# 0          Bay of PlentyBay of Plentyarea
# 1          Bay of PlentyBay of Plentyarea
# 2                        AucklandAuckland
# 3                  SouthlandSouthlandarea
# 4                CanterburyCanterburyarea

# %%
# split and drop repeat word
def drop_repeat(s):
    for x in range(1, len(s)):
        suffix = s[-x:]
        if s.startswith(suffix):
            return (s[:-x], suffix)

# %%
df_copy.head(5)
# Out:
#                                Position  \
# 0                         Administrator
# 1                          Receptionist
# 2          Prosecutions Support Officer
# 3  Early Childhood Centre Administrator
# 4        Business Support Administrator
#
#                                                 Link  \
# 0  https://www.seek.co.nz/job/50582301?type=promo...
# 1  https://www.seek.co.nz/job/50620889?type=promo...
# 2  https://www.seek.co.nz/job/50622169?type=stand...
# 3  https://www.seek.co.nz/job/50639620?type=stand...
# 4  https://www.seek.co.nz/job/50622432?type=stand...
#
#                                     Company  \
# 0                        Private Advertiser
# 1                      Avenues Orthodontics
# 2                        New Zealand Police
# 3  Kew Pacific Island Early Learning Centre
# 4                        Private Advertiser
#
#                                             Location  \
# 0   Bay of PlentyBay of Plentyarea: TaurangaTauranga
# 1   Bay of PlentyBay of Plentyarea: TaurangaTauranga
# 2                                   AucklandAuckland
# 3   SouthlandSouthlandarea: InvercargillInvercargill
# 4   CanterburyCanterburyarea: ChristchurchChristc...
#
#                      Release_time  \
# 0  Featured,at,Private Advertiser
# 1                     Featured,at
# 2                       4d ago,at
# 3                       1h ago,at
# 4    4d ago,at,Private Advertiser
#
#                                       Classification Worktype CompanyID  \
# 0  classification: Administration & Office Suppor...      NaN  50582301
# 1  classification: Administration & Office Suppor...      NaN  50620889
# 2  classification: Administration & Office Suppor...      NaN  50622169
# 3  classification: Administration & Office Suppor...      NaN  50639620
# 4  classification: Administration & Office Suppor...      NaN  50622432
#
#   Salary                             Area
# 0          Bay of PlentyBay of Plentyarea
# 1          Bay of PlentyBay of Plentyarea
# 2                        AucklandAuckland
# 3                  SouthlandSouthlandarea
# 4                CanterburyCanterburyarea

# %% [markdown]
# #### 2.2.6 Deal with column 'Release_time'
# #### non useful word like 'at', 'Private Advertiser' need be deleted

# %%
df_copy['Release_time'] = df_copy['Release_time'].apply(lambda x: x.split(',')[0])

# %%
df_copy.head(5)
# Out:
#                                Position  \
# 0                         Administrator
# 1                          Receptionist
# 2          Prosecutions Support Officer
# 3  Early Childhood Centre Administrator
# 4        Business Support Administrator
#
#                                                 Link  \
# 0  https://www.seek.co.nz/job/50582301?type=promo...
# 1  https://www.seek.co.nz/job/50620889?type=promo...
# 2  https://www.seek.co.nz/job/50622169?type=stand...
# 3  https://www.seek.co.nz/job/50639620?type=stand...
# 4  https://www.seek.co.nz/job/50622432?type=stand...
#
#                                     Company  \
# 0                        Private Advertiser
# 1                      Avenues Orthodontics
# 2                        New Zealand Police
# 3  Kew Pacific Island Early Learning Centre
# 4                        Private Advertiser
#
#                                             Location Release_time  \
# 0   Bay of PlentyBay of Plentyarea: TaurangaTauranga     Featured
# 1   Bay of PlentyBay of Plentyarea: TaurangaTauranga     Featured
# 2                                   AucklandAuckland       4d ago
# 3   SouthlandSouthlandarea: InvercargillInvercargill       1h ago
# 4   CanterburyCanterburyarea: ChristchurchChristc...       4d ago
#
#                                       Classification Worktype CompanyID  \
# 0  classification: Administration & Office Suppor...      NaN  50582301
# 1  classification: Administration & Office Suppor...      NaN  50620889
# 2  classification: Administration & Office Suppor...      NaN  50622169
# 3  classification: Administration & Office Suppor...      NaN  50639620
# 4  classification: Administration & Office Suppor...      NaN  50622432
#
#   Salary                             Area
# 0          Bay of PlentyBay of Plentyarea
# 1          Bay of PlentyBay of Plentyarea
# 2                        AucklandAuckland
# 3                  SouthlandSouthlandarea
# 4                CanterburyCanterburyarea

# %% [markdown]
# #### 2.2.7 Deal with Column Classification

# %%
print(df_copy['Classification'].str.contains("\d+").sum()) # 96 rows were filled by salary
# Out:
# 96

# %%
df_copy['Classification'] = df_copy['Classification'].apply(lambda x: x.split(':')[1] if ":" in x else "")

# %%
df_copy.head(5)
# Out:
#                                Position  \
# 0                         Administrator
# 1                          Receptionist
# 2          Prosecutions Support Officer
# 3  Early Childhood Centre Administrator
# 4        Business Support Administrator
#
#                                                 Link  \
# 0  https://www.seek.co.nz/job/50582301?type=promo...
# 1  https://www.seek.co.nz/job/50620889?type=promo...
# 2  https://www.seek.co.nz/job/50622169?type=stand...
# 3  https://www.seek.co.nz/job/50639620?type=stand...
# 4  https://www.seek.co.nz/job/50622432?type=stand...
#
#                                     Company  \
# 0                        Private Advertiser
# 1                      Avenues Orthodontics
# 2                        New Zealand Police
# 3  Kew Pacific Island Early Learning Centre
# 4                        Private Advertiser
#
#                                             Location Release_time  \
# 0   Bay of PlentyBay of Plentyarea: TaurangaTauranga     Featured
# 1   Bay of PlentyBay of Plentyarea: TaurangaTauranga     Featured
# 2                                   AucklandAuckland       4d ago
# 3   SouthlandSouthlandarea: InvercargillInvercargill       1h ago
# 4   CanterburyCanterburyarea: ChristchurchChristc...       4d ago
#
#                                       Classification Worktype CompanyID  \
# 0   Administration & Office SupportAdministration...      NaN  50582301
# 1   Administration & Office SupportAdministration...      NaN  50620889
# 2   Administration & Office SupportAdministration...      NaN  50622169
# 3   Administration & Office SupportAdministration...      NaN  50639620
# 4   Administration & Office SupportAdministration...      NaN  50622432
#
#   Salary                             Area
# 0          Bay of PlentyBay of Plentyarea
# 1          Bay of PlentyBay of Plentyarea
# 2                        AucklandAuckland
# 3                  SouthlandSouthlandarea
# 4                CanterburyCanterburyarea

# %%
df_copy.to_excel("NZ_Admin_JOBS_1.xlsx")
